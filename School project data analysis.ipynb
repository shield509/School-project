# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\hafiz\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_June_2019.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13622 entries, 0 to 13621
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          13579 non-null  object
#  1   Product           13579 non-null  object
#  2   Quantity Ordered  13579 non-null  object
#  3   Price Each        13579 non-null  object
#  4   Order Date        13579 non-null  object
#  5   Purchase Address  13579 non-null  object
# dtypes: object(6)
# memory usage: 638.7+ KB

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
a=df['Product']
b=a.mode()[0]
print(b)
# Out:
# Lightning Charging Cable

# %%
value_counts = df['Price Each'].value_counts()

# Find the minimum count
min_count = value_counts.min()
print(min_count)
# Out:
# 3

# %%
df.shape
# Out:
# (13622, 6)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
a=df['Product'].value_counts()
plt.figure(figsize=(10,8))
plt.bar(a.index,a.values,color='blue')
plt.xlabel('Product')
plt.ylabel('Count')
plt.title('Product distribution in june 2009')
plt.xticks(rotation=90)
plt.show()

# %%
# Create the line chart
plt.figure(figsize=(12, 9))
plt.plot(product_counts.index, product_counts.values, marker='o', linestyle='-', color='b')
plt.xlabel('Product')
plt.ylabel('Count')
plt.title('Product Distribution in June 2019')
plt.xticks(rotation=90)  # Rotate the product names for better readability
plt.grid(True)
plt.show()
